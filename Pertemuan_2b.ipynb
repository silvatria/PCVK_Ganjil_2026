# %% [markdown]
# <a href="https://colab.research.google.com/github/silvatria/PCVK_Ganjil_2026/blob/main/Pertemuan_2b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import cv2
import matplotlib.pyplot as plt
import numpy as np

# uploaded = files.upload()
# nama_file = "KTM_CONTOH.jpg"

# img = cv2.imread(nama_file)

# # Plot gambar asli (warnanya bakal aneh karena masih BGR)
# plt.figure(figsize=(10, 5))
# plt.subplot(1, 2, 1)
# plt.imshow(img)
# plt.title("Format BGR Asli")

# # Konversi ke RGB biar normal
# img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# plt.subplot(1, 2, 2)
# plt.imshow(img_rgb)
# plt.title("Setelah Konversi RGB")
# plt.show()

# img_gray = cv2.imread(nama_file, cv2.IMREAD_GRAYSCALE)

# plt.figure(figsize=(15, 5))

# # Tanpa cmap (Matplotlib bakal ngasih warna default kuning-hijau)
# plt.subplot(1, 3, 1)
# plt.imshow(img_gray)
# plt.title("Tanpa cmap")

# # Dengan cmap abu-abu beneran
# plt.subplot(1, 3, 2)
# plt.imshow(img_gray, cmap="gray")
# plt.title("Dengan cmap='gray'")

# # Dengan cmap 'magma'
# plt.subplot(1, 3, 3)
# plt.imshow(img_gray, cmap="magma")
# plt.title("Dengan cmap='magma'")
# plt.show()

# Mengubah ukuran gambar RGB menjadi 400x250 pixel
# imgRGBsmall = cv2.resize(img_rgb, (400, 250))

# plt.imshow(imgRGBsmall)
# plt.title("Hasil Resizing (400x250)")
# plt.show()

# imgBalik = cv2.flip(imgRGBsmall, 1)

# # Tampilkan dengan ukuran kanvas yang lebih besar
# fig = plt.figure(figsize=(10, 10))
# ax = fig.add_subplot(111)
# ax.imshow(imgBalik)
# plt.title("Hasil Flipping Horizontal")
# plt.show()

# Bikin kanvas hitam 512x512 dengan 3 channel (warna)
# black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)

# # 1. Gambar kotak hijau
# cv2.rectangle(black_img, pt1=(384, 0), pt2=(510, 128), color=(0, 255, 0), thickness=10)

# # 2. Gambar kotak biru
# cv2.rectangle(black_img, pt1=(200, 200), pt2=(300, 300), color=(0, 0, 255), thickness=15)

# # 3. Gambar lingkaran merah
# cv2.circle(black_img, center=(100, 100), radius=50, color=(255, 0, 0), thickness=8)

# # 4. Gambar garis putih diagonal
# cv2.line(black_img, pt1=(0, 0), pt2=(512, 512), color=(255, 255, 255), thickness=5)

# # 5. Tulis Teks "Hello"
# font = cv2.FONT_HERSHEY_SIMPLEX
# cv2.putText(black_img, text='Hello', org=(10, 500), fontFace=font, fontScale=4, color=(255, 255, 0), thickness=2, lineType=cv2.LINE_AA)

# plt.figure(figsize=(8, 8))
# plt.imshow(black_img)
# plt.show()

# Bikin black image kedua dengan tipe data int32
# black_img2 = np.zeros(shape=(512, 512, 3), dtype=np.int32)

# # Inisialisasi array NumPy titik koordinat (vertices)
# vertices = np.array([[100, 300], [200, 200], [400, 300], [200, 400]], dtype=np.int32)

# # Reshape array titik (-1,1,2) buat nunjukin tiap titik diwakili 2 nilai (X,Y) di dalam array 3D
# pts = vertices.reshape((-1, 1, 2))

# # Tambahin polyline (garis bersambung membentuk bangun) warna merah
# cv2.polylines(black_img2, [pts], isClosed=True, color=(255, 0, 0), thickness=5)

# # Tampilkan hasilnya
# plt.figure(figsize=(6, 6))
# plt.imshow(black_img2)
# plt.title("Black Image 2: Polylines")
# plt.show()

# praktikum 3
import cv2 as cv
from google.colab.patches import cv2_imshow

# image = cv.imread("KTM_CONTOH.jpg")

# # praktikum 3
# img_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# # Red-Blue saja (Green di-nol-kan, index 1 = Green)
# img_rb = img_rgb.copy()
# img_rb[:, :, 1] = 0
# print("Red-Blue saja:")
# cv2_imshow(cv.cvtColor(img_rb, cv.COLOR_RGB2BGR))

# # Green-Blue saja (Red di-nol-kan, index 0 = Red)
# img_gb = img_rgb.copy()
# img_gb[:, :, 0] = 0
# print("Green-Blue saja:")
# cv2_imshow(cv.cvtColor(img_gb, cv.COLOR_RGB2BGR))


# # Load gambar utama lu
# image = cv.imread("KTM_CONTOH.jpg")

# # Slicing array NumPy: [baris_awal:baris_akhir, kolom_awal:kolom_akhir]
# img_crop = image[20:115, 25:120]
# cv2_imshow(img_crop)

# # OpenCV membaca dalam BGR, jadi Red ada di index 2
# img_red_only = image[5:30, :, 2]

# # Hasilnya akan tampil seperti gambar grayscale yang mewakili intensitas warna merah
# cv2_imshow(img_red_only)

# import random

# img_kotak = image.copy()
# h, w = img_kotak.shape[:2]

# for _ in range(5):
#     # Random warna BGR dan posisi koordinat
#     color = (random.randint(0,255), random.randint(0,255), random.randint(0,255))
#     x1, y1 = random.randint(0, w-50), random.randint(0, h-50)
#     x2, y2 = random.randint(x1+10, w), random.randint(y1+10, h)

#     cv.rectangle(img_kotak, (x1, y1), (x2, y2), color, -1) # -1 untuk fill kotak

# cv2_imshow(img_kotak)

# 0 untuk flip vertikal (atas-bawah), 1 untuk horizontal (kiri-kanan), -1 untuk keduanya
# img_terbalik = cv.flip(image, 0)
# cv2_imshow(img_terbalik)

# import cv2 as cv
# from google.colab import files
# from google.colab.patches import cv2_imshow


# print("Silakan upload foto aktivitas lu:")
# uploaded = files.upload()

# nama_file = list(uploaded.keys())[0]


# img_aktivitas = cv.imread(nama_file)


# if img_aktivitas is not None:
#     # Kordinat (x,y) tinggal lu sesuaikan sama posisi wajah asli di foto
#     cv.rectangle(img_aktivitas, (150, 100), (300, 300), (0, 255, 0), 5) # Kotak hijau
#     cv.circle(img_aktivitas, (225, 200), 80, (0, 0, 255), 3) # Lingkaran merah

#     # Tampilkan hasilnya
#     cv2_imshow(img_aktivitas)
# else:
#     print("Error ! Gambar gagal dibaca, coba upload ulang file yang bener.")

# import cv2 as cv
# from google.colab import files
# from google.colab.patches import cv2_imshow

# # Upload gambar pilihan lu (kitten/lena/mandrill/dsb)
# print("Upload gambarnya di sini:")
# uploaded = files.upload()
# nama_file = list(uploaded.keys())[0]

# # Baca gambar
# img = cv.imread(nama_file)

# if img is not None:

#     img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

#     img_blue = img_rgb.copy()
#     img_blue[:, :, 0] = 0
#     img_blue[:, :, 1] = 0


#     tinggi, lebar = img_blue.shape[:2]

#     cv.rectangle(img_blue, (0, tinggi - 150), (300, tinggi), (255, 255, 255), 5)

#     font = cv.FONT_HERSHEY_DUPLEX
#     cv.putText(img_blue, nama_file, (15, tinggi - 70), font, 1.2, (0, 255, 255), 3, cv.LINE_AA)

#     # Tampilkan hasilnya (balikin ke BGR dulu biar warnanya bener pas di-show)
#     cv2_imshow(cv.cvtColor(img_blue, cv.COLOR_RGB2BGR))
# else:
#     print("Error: Gambar gagal diload.")

import cv2 as cv
from google.colab.patches import cv2_imshow

img = cv.imread('KTM_CONTOH.jpg') # atau ganti nama file KTM full lu

if img is not None:
    # Ambil ukuran tinggi dan lebar gambar asli secara otomatis
    tinggi, lebar = img.shape[:2]

    # Kita tentukan posisi berdasarkan titik tengah/kanan bawah gambar penuh
    # (Lu bisa ubah angka pembaginya kalau posisinya masih kurang pas)

    # 1. Kotak MONTH/YEAR (biasanya di tengah agak ke kanan atas)
    cv.rectangle(img, (int(lebar * 0.55), int(tinggi * 0.45)), (int(lebar * 0.75), int(tinggi * 0.55)), (0, 0, 0), -1)

    # 2. Kotak VALID THRU (di tengah agak ke kiri sedikit di bawahnya)
    cv.rectangle(img, (int(lebar * 0.45), int(tinggi * 0.57)), (int(lebar * 0.54), int(tinggi * 0.67)), (255, 0, 0), -1)

    # 3. Kotak Angka 02/26 (di sebelah kanan Valid Thru)
    cv.rectangle(img, (int(lebar * 0.55), int(tinggi * 0.57)), (int(lebar * 0.75), int(tinggi * 0.67)), (0, 0, 255), -1)

    # Tampilkan hasil
    cv2_imshow(img)
else:
    print("Gambarnya gagal diload!")
# Out:
# <PIL.Image.Image image mode=RGB size=1363x772>
