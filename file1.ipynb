# %% [markdown]
# <a href="https://colab.research.google.com/github/silvatria/PCVK_Ganjil_2026/blob/main/file1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
"https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg"]

# for url in urls:
#   image = io.imread(url)
#   image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
#   image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
#   final_frame = cv.hconcat((image, image_2))
#   cv2_imshow(final_frame)
#   print('\n')

# tinggi = image_2.shape[0]
# lebar = image_2.shape[1]
# print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
# cv2_imshow(image_2)

# image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
# image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# print('\n')

# #membuat garis horizontal ditengah image
# for y in range (lebar):
#   image_3[int((tinggi)/2),y] = [255,255,255]

# final_frame = cv.hconcat((image_2, image_3))
# cv2_imshow(final_frame)

print('\n')

# praktikum 2

# 1. Membuat Garis Vertikal Saja
image_vertikal = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
    image_vertikal[x, int(lebar/2)] = [255, 255, 255]

print("Gambar Garis Vertikal:")
cv2_imshow(image_vertikal)


# 2. Membuat Garis Menyilang Diagonal Saja (Membentuk X)
image_diagonal = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(lebar):
    # Diagonal dari kiri atas ke kanan bawah
    x1 = int((tinggi / lebar) * y)
    if x1 < tinggi:
        image_diagonal[x1, y] = [255, 255, 255]

    # Diagonal dari kiri bawah ke kanan atas
    x2 = int(tinggi - 1 - (tinggi / lebar) * y)
    if 0 <= x2 < tinggi:
        image_diagonal[x2, y] = [255, 255, 255]

print("Gambar Garis Menyilang Diagonal:")
cv2_imshow(image_diagonal)

image_horizontal = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# 3. Menentukan batas awal dan akhir garis (panjang tertentu)
start_x = int(lebar / 4)
end_x = int((lebar / 4) * 3)

# Mengubah kumpulan pixel menjadi putih di koordinat Y (tengah) dan rentang X (start_x sampai end_x)
for x in range(start_x, end_x):
    image_horizontal[int(tinggi/2), x] = [255, 255, 255]

print("Gambar Garis Horizontal Panjang Tertentu:")
cv2_imshow(image_horizontal)

image_kotak = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# 4. Menentukan posisi sembarang, misal kotak ukuran 100x100 dari koordinat (50, 50)
y_start = 50
y_end = 150
x_start = 50
x_end = 150

# Mewarnai kumpulan pixel menjadi putih (membentuk kotak)
for y in range(y_start, y_end):
    for x in range(x_start, x_end):
        # Cek batas aman biar gak error kalau ukuran gambar aslinya kekecilan
        if y < tinggi and x < lebar:
            image_kotak[y, x] = [255, 255, 255]

print("Gambar Kotak Kumpulan Pixel Putih:")
cv2_imshow(image_kotak)
# Out:
# Gambar Garis Vertikal:
# <PIL.Image.Image image mode=RGB size=400x286>
# Gambar Garis Menyilang Diagonal:
# <PIL.Image.Image image mode=RGB size=400x286>
# Gambar Garis Horizontal Panjang Tertentu:
# <PIL.Image.Image image mode=RGB size=400x286>
# Gambar Kotak Kumpulan Pixel Putih:
# <PIL.Image.Image image mode=RGB size=400x286>
