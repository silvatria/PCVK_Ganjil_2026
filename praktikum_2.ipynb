# %% [markdown]
# <a href="https://colab.research.google.com/github/silvatria/PCVK_Ganjil_2026/blob/main/praktikum_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
image_tugas2 = cv.cvtColor("https://i.postimg.cc/HxZXnmz9/Screenshot-2026-09-03-205134.png", cv.COLOR_BGR2RGB)

# Garis vertikal di tengah
for x in range(tinggi):
    image_tugas2[x, int(lebar/2)] = [255, 255, 255]

# Garis menyilang diagonal (kiri atas ke kanan bawah)
batas = min(tinggi, lebar)
for i in range(batas):
    image_tugas2[i, i] = [255, 255, 255]

cv2_imshow(image_tugas2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3558/1790470560.py in <cell line: 0>()
# ----> 1 image_tugas2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
#       2
#       3 # Garis vertikal di tengah
#       4 for x in range(tinggi):
#       5     image_tugas2[x, int(lebar/2)] = [255, 255, 255]
#
# NameError: name 'cv' is not defined
